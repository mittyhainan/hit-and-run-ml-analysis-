# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Kaiyuan Yang
# - Hainan Xiong
# - Keshan Chen
# - Jinzong Que

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# We want to predict whether a collison will involve hit and run given various factors, including traffic volumn, locatin of streetlight, streetlight types, different area of San Diego, time of incidents happen, type of collisions. We believe this will help the policemen to determine whether they should send more people to handle the incident in order to prevent hit and run and its consequence.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name:pd_collisions_datasd_v1.csv
# - Link to the dataset:https://data.sandiego.gov/datasets/police-collisions/
# - Number of observations before cleanning: 60461
# This dataset is recorded by San Diego Police Department. The data is up-to-date since 2015. The dataset includes information about the report_id, the time the incidents happen, the address of the incidents, violation types, number of people killed or injured in the incident, and whether the collision involves hit&run,
# - Dataset Name:streetlight_locations_datasd_v1.csv
# - Link to the dataset:https://data.sandiego.gov/datasets/streetlight_inventory/
# - Number of observations before cleanning: 61229
# This dataset is recorded by SDPD as well. The dataset includes streetlight ID in SAP, streetlight models, streetlight longitute and latitude, and the locations of the streetlights.
# - Dataset Name:streetlight_locations_datasd_v1.csv
# - Link to the dataset:https://data.sandiego.gov/datasets/streetlight_inventory/
# - Number of observations before cleanning: 61229
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
collision_data = pd.read_csv('pd_collisions_datasd_v1.csv')
collision_data
#streetlight_data = pd.read_csv('streetlight_locations_datasd_v1.csv')
#streetlight_data
# Out:
# /Users/mittyhainan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       report_id            date_time police_beat  address_no_primary  \
# 0        500098  2015-01-01 00:01:00         725                6000
# 1        500002  2015-01-01 00:01:00         627                3700
# 2        500436  2015-01-01 01:35:00         712                 100
# 3        500166  2015-01-01 02:00:00         438                2600
# 4        500429  2015-01-01 02:30:00         813                4600
# ...         ...                  ...         ...                 ...
# 60456  21200749  2021-02-08 12:50:00         725                1200
# 60457  21200759  2021-02-08 13:21:44         524                1300
# 60458  21200755  2021-02-08 15:10:00         611                   0
# ...

# %%
streetlight_data = pd.read_csv('streetlight_locations_datasd_v1.csv')
streetlight_data
# Out:
#               sap_id   streetlight_model streetlight_type  \
# 0      SS-015619-001               COBRA              IND
# 1      SS-015617-002               COBRA              IND
# 2      SS-005044-001               COBRA              IND
# 3      SS-004379-003               COBRA              IND
# 4      SS-004379-004               COBRA              IND
# ...              ...                 ...              ...
# 61224            NaN  BALLPARK LIGHTIING          UNKNOWN
# 61225            NaN  BALLPARK LIGHTIING          UNKNOWN
# 61226            NaN  BALLPARK LIGHTIING          UNKNOWN
# 61227            NaN  BALLPARK LIGHTIING          UNKNOWN
# 61228            NaN  BALLPARK LIGHTIING          UNKNOWN
#
#        streetlight_wattage  streetlight_voltage         lng        lat  \
# 0                     85.0                120.0 -117.252424  32.864282
# 1                     85.0                120.0 -117.250892  32.872267
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# # Project Proposal (updated)

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/20  |  1 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/26  |  10 AM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 2/1  | 10 AM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/14  | 6 PM  | Import & Wrangle Data (Ant Man); EDA (Hulk) | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 2/23  | 12 PM  | Finalize wrangling/EDA; Begin Analysis (Iron Man; Thor) | Discuss/edit Analysis; Complete project check-in |
# | 3/13  | 12 PM  | Complete analysis; Draft results/conclusion/discussion (Wasp)| Discuss/edit full project |
# | 3/19  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
