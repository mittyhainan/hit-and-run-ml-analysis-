# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Ant Man
# - Hulk
# - Iron Man
# - Thor
# - Wasp

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# *Fill in your research question here*

# %% [markdown]
# # Setup

# %%
## YOUR CODE HERE

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
import pandas as pd
import numpy as np
collision = pd.read_csv('pd_collisions_datasd_v1.csv')
collision
# Out:
# /Users/yangkaiyuan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       report_id            date_time police_beat  address_no_primary  \
# 0        500098  2015-01-01 00:01:00         725                6000
# 1        500002  2015-01-01 00:01:00         627                3700
# 2        500436  2015-01-01 01:35:00         712                 100
# 3        500166  2015-01-01 02:00:00         438                2600
# 4        500429  2015-01-01 02:30:00         813                4600
# ...         ...                  ...         ...                 ...
# 60456  21200749  2021-02-08 12:50:00         725                1200
# 60457  21200759  2021-02-08 13:21:44         524                1300
# 60458  21200755  2021-02-08 15:10:00         611                   0
# ...

# %%
streetlight = pd.read_csv('streetlight_locations_datasd_v1.csv')
temp = streetlight.dropna()
streetlight = temp.drop(columns = ['sap_id','streetlight_wattage','streetlight_voltage'])
streetlight
# Out:
#       streetlight_model streetlight_type         lng        lat  \
# 0                 COBRA              IND -117.252424  32.864282
# 1                 COBRA              IND -117.250892  32.872267
# 2                 COBRA              IND -117.246841  32.881493
# 3                 COBRA              IND -117.248476  32.885452
# 4                 COBRA              IND -117.247382  32.885273
# ...                 ...              ...         ...        ...
# 54706             COBRA              IND -117.120433  32.763269
# 54709             COBRA              IND -117.120791  32.763430
# 54710             COBRA              IND -117.120586  32.763474
# 54711             COBRA              IND -117.120727  32.763240
# 54723             COBRA              IND -117.149651  32.749430
#
#                                   location_description
# 0          LA JOLLA SHORES DR @ RUETTE MONTE CARLO N/E
# 1      LA JOLLA SHORES LN N/O LA JOLLA SHORES DR @ CDS
# ...

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
